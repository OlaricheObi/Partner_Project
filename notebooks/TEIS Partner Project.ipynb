# %% [markdown]
# # Import necessary packages

# %%
import pandas as pd

# %% [markdown]
# ## Read in the first page of the excel file. Notice that it has several table with flawwed formatting...

# %%
reported_data = pd.read_excel('../data/TEIS Exit Data for NSS.xlsx', sheet_name = 'Reported Data', skiprows = 4)
reported_data

# %% [markdown]
# ### Reading in the first sheet we skipped 4 rows, *including* the row which says the targeted number for the outcomme.

# %%
reported_data.rename(columns = {'Unnamed: 0': 'POE'}, inplace = True)

# %%
reported_data
# Out:
#             POE   OC1 - a   OC1 - b   OC1 - c   OC1 - d   OC1 - e   OC1 Total  \
# 0            ET         0       155       214       392       138         899
# 1            FT         0       121       122       234       102         579
# 2            GN         8       294       215       246       124         887
# 3            MD         4       315       203       148        51         721
# 4            NW         0        68        69        74        11         222
# 5            SC         1       207       240       249       118         815
# 6            SE         0        81        92       137        66         376
# 7            SW         0        87        76        71        28         262
# 8            UC         0       128       160       182        49         519
# 9   Grand Total        13      1456      1391      1733       687        5280
# 10          NaN       NaN       NaN       NaN       NaN       NaN         NaN
# ...

# %%
for index, row in reported_data.iterrows():
    value = row['']

# %%
reported_data[]

# %%
reported_totals = pd.read_excel('../data/TEIS Exit Data for NSS.xlsx', sheet_name = 'Reported Totals')
reported_totals
# Out:
#                                           Unnamed: 0  Unnamed: 1
# 0                        Children exiting with IFSP       8441.0
# 1                                                NaN         NaN
# 2  Children with <182 days btw Initial IFSP and E...      2471.0
# 3  Children with >= 182 days btw Initial IFSP and...      5970.0
# 4  Children with entrance and exit ECO data\n(tak...      5280.0
# 5                           Records missing ECO data       690.0

# %%
eco = pd.read_excel('../data/TEIS Exit Data for NSS.xlsx', sheet_name = 'ECO with Exit20-21')
eco
# Out:
#      DISTRICT                                           CHILD_ID  \
# 0          ET                                             456849
# 1          ET                                             490916
# 2          ET                                             426757
# 3          ET                                             480611
# 4          ET                                             492863
# ...       ...                                                ...
# 8443      NaN                                                NaN
# 8444      NaN                                                NaN
# 8445      NaN                                                NaN
# 8446      NaN  Corrected Child ID 475887 impossible combinati...
# 8447      NaN  Corrected Child ID 486516 impossible combinati...
#
#      ECO_Entry_DATE  Ent SOCIAL_SCALE  Ent KNOWLEDGE_SCALE  \
# 0        2019-04-24               3.0                  5.0
# 1               NaT               NaN                  NaN
# ...

# %%
exit_notes = pd.read_excel('../data/TEIS Exit Data for NSS.xlsx', sheet_name = 'Exit Notes')
exit_notes
# Out:
#      POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 0     UC    471738 2019-02-28        2019-10-17               2019-10-29
# 1     FT    449030 2018-07-22        2018-11-07               2018-12-03
# 2     FT    463311 2017-07-09        2019-05-24               2019-06-19
# 3     FT    463313 2017-07-09        2019-05-24               2019-06-19
# 4     FT    469194 2017-08-31        2019-09-04               2019-10-02
# ...   ..       ...        ...               ...                      ...
# 5577  MD    491609 2018-12-22        2020-10-20               2020-10-30
# 5578  GN    491743 2018-06-05        2020-10-22               2020-11-05
# 5579  ET    491879 2019-04-24        2020-10-26               2020-11-02
# 5580  SC    492267 2018-06-01        2020-10-30               2020-11-17
# 5581  SW    492408 2020-08-06        2020-11-03               2020-11-17
#
#      Initial IFSP Date Latest IFSP Date  \
# 0           2019-10-31       2020-05-12
# ...

# %%
terms_dict = pd.read_excel('../data/TEIS Exit Data for NSS.xlsx', sheet_name = 'Terms-Acronyms')
terms_dict
# Out:
#                                          Term/Acronym  \
# 0                                                 619
# 1                    Board certified behavior analyst
# 2                                              (BCBA)
# 3   Battelle Developmental Inventory 2 Normative U...
# 4                                          (BDI-2 NU)
# 5     Certified occupational therapy assistant (COTA)
# 6                         District administrator (DA)
# 7                          Developmental therapy (DT)
# 8                            Early Childhood Outcomes
# 9                                               (ECO)
# 10                              Early interventionist
# 11                                               (EI)
# 12       Early Intervention Resource Agencies (EIRAs)
# 13  Individuals with Disabilities Education Act (I...
# 14          Individualized Family Service Plan (IFSP)
# 15                       Local Education Agency (LEA)
# ...
